# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = sns.load_dataset("penguins")
df=df.dropna()

def per(a):
    return f"{a.sum()/len(df):.4f}"

print(df.head())

A=df['species']=='Adelie'
B=df['flipper_length_mm']>=200
C=df['island']=='Biscoe'
D=df['sex']=='Male'
E=df['body_mass_g']>=4000
F=df['bill_length_mm']>= np.mean(df['bill_length_mm'])
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
print(f'A와 D의 곱사건: {per(A&D)}')
print(f'A와 C의 합사건: {per(A|C)}')
print(f'B와 E의 곱사건: {per(B&E)}')
print(f'D의 여사건과 E의 곱사건: {per((~D)&E)}')
# Out:
# A와 D의 곱사건: 0.2192
# A와 C의 합사건: 0.7958
# B와 E의 곱사건: 0.4114
# D의 여사건과 E의 곱사건: 0.1742
