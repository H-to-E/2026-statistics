# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = sns.load_dataset("penguins")
df=df.dropna()

def per(a):
    return f"{a.sum()/len(df):.4f}"

df.head()

A=df['species']=='Adelie'
B=df['flipper_length_mm']>=200
C=df['island']=='Biscoe'
D=df['sex']=='Male'
E=df['body_mass_g']>=4000
F=df['bill_length_mm']>= np.mean(df['bill_length_mm'])

# %%
plt.boxplot(df['bill_length_mm'])
plt.title('length boxplot')
plt.ylabel('mm')
plt.show()

# %%
df.boxplot(column='bill_length_mm',by='species')
plt.title('length boxplot', )
plt.ylabel('mm')
plt.show()
