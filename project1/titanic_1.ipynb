# %%
from sklearn.datasets import fetch_openml
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statistics import mode
from scipy import stats
from scipy.stats import variation

X,y= fetch_openml("titanic",version=1,as_frame=True,return_X_y=True,parser='auto')

# %%
cols =['pclass','age','sibsp','parch','fare']
stats =[]

for col in cols:
    s= X[col].dropna()
    median = s.median()
    mode = s.mode().iloc[0]
    mean = s.mean()
    cv= variation(s)*100
    stats.append({'Variable':col,'Median':median,'Mode':mode_,'Mean':mean,'CV(%)':round(cv,2)})
df_st=pd.DataFrame(stats)
print(df_st)
# Out:
#   Variable   Median  Mode       Mean   CV(%)
# 0   pclass   3.0000  8.05   2.294882   36.49
# 1      age  28.0000  8.05  29.881135   48.21
# 2    sibsp   0.0000  8.05   0.498854  208.73
# 3    parch   0.0000  8.05   0.385027  224.72
# 4     fare  14.4542  8.05  33.295479  155.39
