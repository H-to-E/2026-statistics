# %%
from sklearn.datasets import fetch_openml
import pandas as pd
import numpy as np

X,y=fetch_openml("titanic",version=1,as_frame=True,return_X_y=True,parser='auto')

df=pd.concat([X,y],axis=1)
df=df[['pclass','sex','age','sibsp','parch','fare','embarked','survived']]

df['survived']=df['survived'].astype(int)
df['pcalss']=df['pclass'].astype(int)
df= df.dropna().reset_index(drop=True)

# %%
alone=(df['sibsp']==0)&(df['parch']==0)
survive=(df['survived']==1)

pera=alone.sum()/len(df)
pers=survive.sum()/len(df)
peras=(alone&survive).sum()/len(df)

if peras==(pera*pers):
    print('두 사건은 독립')
else:
    print('두 사건은 종속')
# Out:
# 두 사건은 종속
